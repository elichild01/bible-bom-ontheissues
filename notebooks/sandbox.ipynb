# %%
import json
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../results/concordance_1.csv')
for _, thing in df[df['god_body_support_1'] == .9].iterrows():
    print(thing['text'])
# Out:
# But who is able to build him an house, seeing the heaven and heaven of heavens cannot contain him? who [am] I then, that I should build him an house, save only to burn sacrifice before him?

# %%
dfs = [pd.read_csv(f'../results/concordance_{i}.csv') for i in range(1, 7)]

df = pd.concat(dfs)
df.sort_values('god_body_support_1', ascending=False)['text'].head()

df.to_csv('../results/concordance.csv', index=False)

# %%
dfllm = pd.read_csv('../results/concordance.csv')

for verse in dfllm.sort_values('god_body_support_1', ascending=False).head(10)['text']:
    print(verse)
# Out:
# But who is able to build him an house, seeing the heaven and heaven of heavens cannot contain him? who [am] I then, that I should build him an house, save only to burn sacrifice before him?
# God [is] a Spirit: and they that worship him must worship [him] in spirit and in truth.
# If I ascend up into heaven, thou [art] there: if I make my bed in hell, behold, thou [art there].
# God that made the world and all things therein, seeing that he is Lord of heaven and earth, dwelleth not in temples made with hands;
# For [he is] not a man, as I [am, that] I should answer him, [and] we should come together in judgment.
# Yea, they durst not make use of that which is their own lest they should offend their priests, who do yoke them according to their desires, and have brought them to believe, by their traditions and their dreams and their whims and their visions and their pretended mysteries, that they should, if they did not do according to their words, offend some unknown being, who they say is God—a being who never has been seen or known, who never was nor ever will be.
# Can any hide himself in secret places that I shall not see him? saith the LORD. Do not I fill heaven and earth? saith the LORD.
# Whither shall I go from thy spirit? or whither shall I flee from thy presence?
# But will God in very deed dwell with men on the earth? behold, heaven and the heaven of heavens cannot contain thee; how much less this house which I have built!
# Howbeit the most High dwelleth not in temples made with hands; as saith the prophet,

# %%
dfemb = pd.read_csv('../results/concordance_embedded_0.csv')

for verse in dfemb.sort_values('god_body_viewpoint_1_embed_sim', ascending=False).head(10)['text']:
    print(verse)
# Out:
# Can any hide himself in secret places that I shall not see him? saith the LORD. Do not I fill heaven and earth? saith the LORD.
# God that made the world and all things therein, seeing that he is Lord of heaven and earth, dwelleth not in temples made with hands;
# [Am] I a God at hand, saith the LORD, and not a God afar off?
# But will God indeed dwell on the earth? behold, the heaven and heaven of heavens cannot contain thee; how much less this house that I have builded?
# But will God in very deed dwell with men on the earth? behold, heaven and the heaven of heavens cannot contain thee; how much less this house which I have built!
# One God and Father of all, who [is] above all, and through all, and in you all.
# Believe in God; believe that he is, and that he created all things, both in heaven and in earth; believe that he has all wisdom, and all power, both in heaven and in earth; believe that man doth not comprehend all the things which the Lord can comprehend.
# Behold, God [is] great, and we know [him] not, neither can the number of his years be searched out.
# God [is] a Spirit: and they that worship him must worship [him] in spirit and in truth.
# Neither shall they say, Lo here! or, lo there! for, behold, the kingdom of God is within you.

# %%
df = pd.merge(dfllm, dfemb, on=['text', 'is_bible', 'book', 'chapter', 'verse'], suffixes=('_llm', '_emb'))
df.drop(columns='is_bible', inplace=True)
df = df.rename(columns={'god_body_relevance':'relevance_llm', 'god_body_embed_sim':'relevance_emb',
                        'god_body_support_1':'support_vp1_llm', 'god_body_viewpoint_1_embed_sim':'support_vp1_emb',
                        'god_body_support_2':'support_vp2_llm', 'god_body_viewpoint_2_embed_sim':'support_vp2_emb'})
df.loc[:,'relevance_emb':'support_vp2_emb'] = df.loc[:,'relevance_emb':'support_vp2_emb']**2
# Normalize columns
df.loc[:,'relevance_llm':'support_vp2_emb'] -= df.loc[:,'relevance_llm':'support_vp2_emb'].mean(axis=0)
df.loc[:,'relevance_llm':'support_vp2_emb'] /= df.loc[:,'relevance_llm':'support_vp2_emb'].std(axis=0)
plt.hist(df['support_vp1_llm'], bins=50)
plt.show()

df['composite_relevance'] = df['relevance_llm'] + df['relevance_emb']
df['composite_support_vp1'] = df['support_vp1_llm'] + df['support_vp1_emb']
df['composite_support_vp2'] = df['support_vp2_llm'] + df['support_vp2_emb']


analyze_col = 'composite_support_vp1'
for verse in df.sort_values(analyze_col, ascending=False).head(10)['text']:
    print(verse)
df.sort_values(analyze_col, ascending=False).head(10)
# Out:
# Can any hide himself in secret places that I shall not see him? saith the LORD. Do not I fill heaven and earth? saith the LORD.
# God [is] a Spirit: and they that worship him must worship [him] in spirit and in truth.
# God that made the world and all things therein, seeing that he is Lord of heaven and earth, dwelleth not in temples made with hands;
# But will God indeed dwell on the earth? behold, the heaven and heaven of heavens cannot contain thee; how much less this house that I have builded?
# But will God in very deed dwell with men on the earth? behold, heaven and the heaven of heavens cannot contain thee; how much less this house which I have built!
# But who is able to build him an house, seeing the heaven and heaven of heavens cannot contain him? who [am] I then, that I should build him an house, save only to burn sacrifice before him?
# Whither shall I go from thy spirit? or whither shall I flee from thy presence?
# If I ascend up into heaven, thou [art] there: if I make my bed in hell, behold, thou [art there].
# [Am] I a God at hand, saith the LORD, and not a God afar off?
# Howbeit the most High dwelleth not in temples made with hands; as saith the prophet,
#                book  chapter  verse  \
# 19508      Jeremiah       23     24
# 26180          John        4     24
# 27547          Acts       17     24
# 9012        1 Kings        8     27
# 11300  2 Chronicles        6     18
# 11217  2 Chronicles        2      6
# 16246         Psalm      139      7
# 16247         Psalm      139      8
# 19507      Jeremiah       23     23
# 27164          Acts        7     48
#
#                                                     text  relevance_llm  \
# 19508  Can any hide himself in secret places that I s...       6.083216
# 26180  God [is] a Spirit: and they that worship him m...       8.388802
# 27547  God that made the world and all things therein...       6.083216
# 9012   But will God indeed dwell on the earth? behold...       6.083216
# 11300  But will God in very deed dwell with men on th...       6.083216
# 11217  But who is able to build him an house, seeing ...       8.388802
# 16246  Whither shall I go from thy spirit? or whither...       4.930423
# 16247  If I ascend up into heaven, thou [art] there: ...       4.930423
# 19507  [Am] I a God at hand, saith the LORD, and not ...       4.930423
# 27164  Howbeit the most High dwelleth not in temples ...       6.083216
#
#        support_vp1_llm  support_vp2_llm  relevance_emb  support_vp1_emb  \
# 19508        31.556683         0.710032       4.836783        12.240296
# 26180        35.512358         0.710032       7.299817         7.932211
# 27547        31.556683         0.710032       7.429222        11.046347
# 9012         31.556683         0.710032       6.186268         9.775403
# 11300        31.556683         0.710032       6.896598         9.704040
# 11217        35.512358         0.710032       2.524223         4.394168
# 16246        31.556683         0.710032       3.844941         6.850004
# 16247        31.556683         0.710032       1.668446         6.186189
# 19507        27.601008         1.400406       7.244386         9.821036
# 27164        31.556683         0.710032       3.766887         5.624569
#
#        support_vp2_emb  composite_relevance  composite_support_vp1  \
# 19508         1.695885            10.919999              43.796979
# 26180         3.963423            15.688618              43.444569
# 27547         3.310592            13.512437              42.603030
# 9012          1.704729            12.269484              41.332086
# 11300         2.837589            12.979813              41.260723
# 11217         0.454069            10.913024              39.906525
# 16246         0.583559             8.775363              38.406687
# 16247         1.398339             6.598868              37.742872
# 19507         3.014246            12.174809              37.422045
# 27164         0.410793             9.850103              37.181252
#
#        composite_support_vp2
# 19508               2.405917
# 26180               4.673455
# 27547               4.020624
# 9012                2.414761
# 11300               3.547622
# 11217               1.164102
# 16246               1.293591
# 16247               2.108372
# 19507               4.414652
# 27164               1.120825

# %%
# First, fix the voting between LLM and embedding. Even with the squaring, current normalization heavily favors LLM

# Infographics I'd like to make:
    # Top 10 most relevant verses
    # Top 10 verses for each viewpoint
    # Top 10 verses that most support both sides(?) - sort by max of min of two supports
    # Top 10 most relevant books (just sum)
    # Top 10 most relevant chapters (just sum)
    # Top 10 books for each viewpoint
    # Talk about my process, including prompt, a nice statement about 3072-dimensional space, runtime, independent of if verse is Bible/BoM, etc.

# %%
fn = "/Users/elichild/Documents/BYU/ENGL 238/Final Project/bible-bom-ontheissues/cache/0a0abdde5ee7d1411b82ea09098752c122734509.json"
with open(fn, "r", encoding="utf-8") as f:
    sample_embed = json.load(f)

len(sample_embed)
# Out:
# 3072
